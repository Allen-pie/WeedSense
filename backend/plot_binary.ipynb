# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Data ini didapat dari hasil pencatatan manual saat melatih model versi binary classification.

# %%
epochs = list(range(1, 21))

train_loss = [  
                0.0917, 0.0372, 0.0368, 0.0311, 0.0277, 0.0233,  0.0203, 0.0195, 0.0245, 0.0192,  
                0.0177, 0.0171, 0.0166, 0.0161, 0.0157, 0.0157, 0.0152, 0.0150, 0.0146, 0.0147
             ]

valid_loss = [ 
               0.0415, 0.0405, 0.0348, 0.0340, 0.0246, 0.0220, 0.0203, 0.0397, 0.0225, 0.0192, 
               0.0180, 0.0178, 0.0184, 0.0172, 0.0163, 0.0159, 0.0172, 0.0156, 0.0156, 0.0152
             ]

train_dice = [
               0.4239, 0.7077, 0.7240, 0.7708, 0.8021, 0.8266, 0.8405, 0.8436, 0.8172, 0.8456,
               0.8535, 0.8566, 0.8579, 0.8626, 0.8661, 0.8655, 0.8700, 0.8708, 0.8741, 0.8732
            ]
            
valid_dice = [
                0.6474, 0.6708, 0.7294, 0.7906, 0.8242, 0.8354, 0.8353, 0.6910, 0.8472, 0.8517,  
                0.8484, 0.8481, 0.8629, 0.8583, 0.8662, 0.8701, 0.8530, 0.8706, 0.8725, 0.8727
             ]

train_acc = [
                0.9781, 0.9895, 0.9900, 0.9913, 0.9921, 0.9928, 0.9932, 0.9933, 0.9926, 0.9934,
                0.9937, 0.9939, 0.9940, 0.9941, 0.9942, 0.9942, 0.9943, 0.9944, 0.9945, 0.9945
            ]

valid_acc = [   
                0.9882, 0.9890, 0.9903, 0.9904, 0.9926, 0.9927, 0.9931, 0.9895, 0.9931, 0.9935,
                0.9936, 0.9937, 0.9937, 0.9939, 0.9941, 0.9942, 0.9938, 0.9943, 0.9943, 0.9944
            ]


plt.figure(figsize=(15, 5))

# LOSS 
plt.subplot(1, 3, 1)
plt.plot(epochs, train_loss, label='Train Loss', marker='o')
plt.plot(epochs, valid_loss, label='Valid Loss', marker='o')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# DICE SCORE
plt.subplot(1, 3, 2)
plt.plot(epochs, train_dice, label='Train Dice', marker='o')
plt.plot(epochs, valid_dice, label='Valid Dice', marker='o')
plt.title('Dice Score per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Dice Score')
plt.legend()
plt.grid(True)

# ACCURACY
plt.subplot(1, 3, 3)
plt.plot(epochs, train_acc, label='Train Accuracy', marker='o')
plt.plot(epochs, valid_acc, label='Valid Accuracy', marker='o')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 69
#      67 plt.subplot(1, 3, 2)
#      68 plt.plot(epochs, train_dice, label='Train Dice', marker='o')
# ---> 69 plt.plot(epochs, valid_dice, label='Valid Dice', marker='o')
#      70 plt.title('Dice Score per Epoch')
#      71 plt.xlabel('Epoch')
#
# File c:\Users\Allen\Documents\Python Env\environments\derp_learning\lib\site-packages\matplotlib\pyplot.py:2767, in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Allen\Documents\Python Env\environments\derp_learning\lib\site-packages\matplotlib\axes\_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
#    1394 Plot y versus x as lines and/or markers.
#    1395
#    (...)
#    1632 (``'green'``) or hex strings (``'#008000'``).
#    1633 """
#    1634 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636 for line in lines:
#    1637     self.add_line(line)
#
# File c:\Users\Allen\Documents\Python Env\environments\derp_learning\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File c:\Users\Allen\Documents\Python Env\environments\derp_learning\lib\site-packages\matplotlib\axes\_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (20,) and (10,)
